# %% [markdown]
# # Pobieram dane

# %%
import pandas as pd

# %load_ext nb_black
# data = pd.read_excel("C:/Users/Marek/dane_mgr.xlsx")
data = pd.read_excel("C:/Users/Marek/dane_mgr.xlsx")
data
# Out:
#      A1     A2      A3  A4  A5  A6     A7  A8  A9  A10  A11  A12  A13   A14  \
# 0     1  22.08  11.460   2   4   4  1.585   0   0    0    1    2  100  1213
# 1     0  22.67   7.000   2   8   4  0.165   0   0    0    0    2  160     1
# 2     0  29.58   1.750   1   4   4  1.250   0   0    0    1    2  280     1
# 3     0  21.67  11.500   1   5   3  0.000   1   1   11    1    2    0     1
# 4     1  20.17   8.170   2   6   4  1.960   1   1   14    0    2   60   159
# ..   ..    ...     ...  ..  ..  ..    ...  ..  ..  ...  ...  ...  ...   ...
# 685   1  31.57  10.500   2  14   4  6.500   1   0    0    0    2    0     1
# 686   1  20.67   0.415   2   8   4  0.125   0   0    0    0    2    0    45
# 687   0  18.83   9.540   2   6   4  0.085   1   0    0    0    2  100     1
# 688   0  27.42  14.500   2  14   8  3.085   1   1    1    0    2  120    12
# 689   1  41.00   0.040   2  10   4  0.040   0   1    1    0    1  560     1
#
#      Class
# 0        0
# 1        0
# 2        0
# ...

# %% [markdown]
# # Sortuje dane na klasę decyzji 0 oraz 1

# %%
data_decyz_1 = data[data.Class == 1]
data_decyz_1
# Out:
#      A1     A2      A3  A4  A5  A6     A7  A8  A9  A10  A11  A12  A13  A14  \
# 3     0  21.67  11.500   1   5   3  0.000   1   1   11    1    2    0    1
# 4     1  20.17   8.170   2   6   4  1.960   1   1   14    0    2   60  159
# 5     0  15.83   0.585   2   8   8  1.500   1   1    2    0    2  100    1
# 7     0  58.67   4.460   2  11   8  3.040   1   1    6    0    2   43  561
# 10    1  33.50   1.750   2  14   8  4.500   1   1    4    1    2  253  858
# ..   ..    ...     ...  ..  ..  ..    ...  ..  ..  ...  ...  ...  ...  ...
# 684   1  43.00   0.290   1  13   8  1.750   1   1    8    0    2  100  376
# 685   1  31.57  10.500   2  14   4  6.500   1   0    0    0    2    0    1
# 687   0  18.83   9.540   2   6   4  0.085   1   0    0    0    2  100    1
# 688   0  27.42  14.500   2  14   8  3.085   1   1    1    0    2  120   12
# 689   1  41.00   0.040   2  10   4  0.040   0   1    1    0    1  560    1
#
#      Class
# 3        1
# 4        1
# 5        1
# 7        1
# ...

# %%
data_decyz_0 = data[data.Class == 0]
data_decyz_0
# Out:
#      A1     A2      A3  A4  A5  A6     A7  A8  A9  A10  A11  A12  A13   A14  \
# 0     1  22.08  11.460   2   4   4  1.585   0   0    0    1    2  100  1213
# 1     0  22.67   7.000   2   8   4  0.165   0   0    0    0    2  160     1
# 2     0  29.58   1.750   1   4   4  1.250   0   0    0    1    2  280     1
# 6     1  17.42   6.500   2   3   4  0.125   0   0    0    0    2   60   101
# 8     1  27.83   1.000   1   2   8  3.000   0   0    0    0    2  176   538
# ..   ..    ...     ...  ..  ..  ..    ...  ..  ..  ...  ...  ...  ...   ...
# 678   1  25.67   0.290   1   8   4  1.500   0   0    0    1    2  160     1
# 680   1  21.17   0.000   2   8   4  0.500   0   0    0    1    1    0     1
# 681   1  35.25  16.500   1   8   4  4.000   1   0    0    0    2   80     1
# 683   0  48.17   1.335   2   3   7  0.335   0   0    0    0    2    0   121
# 686   1  20.67   0.415   2   8   4  0.125   0   0    0    0    2    0    45
#
#      Class
# 0        0
# 1        0
# 2        0
# ...

# %% [markdown]
# # Dokonuje losowego wycięcia danych z klasy decyzyjnej 0 w stopniu od 10% aż do 60%.
# # Następnie łączę losowo wycięty fragmęnt z klasą decyzyjną 1 tworząc nowy DataFrame

# %% [markdown]
# ## Początkowo :

# %% [markdown]
# ### Losuje 10% wierszy z klasy decyzyjnej 0
# ### 10% = 38 wierszy

# %%
no_samples_1 = 38

# %%
random_slice_1 = data_decyz_0.sample(n=no_samples_1, random_state=0)
merge_data_1 = pd.merge(random_slice_1, data_decyz_1, how="outer")
merge_data_1
# Out:
#      A1     A2     A3  A4  A5  A6     A7  A8  A9  A10  A11  A12  A13  A14  \
# 0     0  26.17   2.00   2   5   3  0.000   0   0    0    1    2  276    2
# 1     1  20.00   7.00   2   8   4  0.500   0   0    0    0    2    0    1
# 2     1  19.42   1.50   1  13   4  2.000   1   0    0    1    2  100   21
# 3     0  18.17  10.00   1  11   8  0.165   0   0    0    0    2  340    1
# 4     1  34.00   4.50   2   6   4  1.000   1   0    0    1    2  240    1
# ..   ..    ...    ...  ..  ..  ..    ...  ..  ..  ...  ...  ...  ...  ...
# 340   1  43.00   0.29   1  13   8  1.750   1   1    8    0    2  100  376
# 341   1  31.57  10.50   2  14   4  6.500   1   0    0    0    2    0    1
# 342   0  18.83   9.54   2   6   4  0.085   1   0    0    0    2  100    1
# 343   0  27.42  14.50   2  14   8  3.085   1   1    1    0    2  120   12
# 344   1  41.00   0.04   2  10   4  0.040   0   1    1    0    1  560    1
#
#      Class
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
# ...

# %%
merge_data_1["Class"].value_counts()
# Out:
# 1    307
# 0     38
# Name: Class, dtype: int64

# %% [markdown]
# ### Przygotowuję dane pod klasyfikację

# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns

# %matplotlib notebook

# %%
dataset_1 = merge_data_1

# %%
dataset_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 345 entries, 0 to 344
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A1      345 non-null    int64
#  1   A2      345 non-null    float64
#  2   A3      345 non-null    float64
#  3   A4      345 non-null    int64
#  4   A5      345 non-null    int64
#  5   A6      345 non-null    int64
#  6   A7      345 non-null    float64
#  7   A8      345 non-null    int64
#  8   A9      345 non-null    int64
#  9   A10     345 non-null    int64
#  10  A11     345 non-null    int64
#  11  A12     345 non-null    int64
#  12  A13     345 non-null    int64
#  13  A14     345 non-null    int64
#  14  Class   345 non-null    int64
# dtypes: float64(3), int64(12)
# memory usage: 43.1 KB

# %%
X_1 = dataset_1.iloc[:, 0:14]
X_1 = X_1.values
Y_1 = dataset_1.iloc[:, -1].values
from sklearn.model_selection import train_test_split

X_train_1, X_test_1, Y_train_1, Y_test_1 = train_test_split(
    X_1, Y_1, test_size=0.25, stratify=Y_1, random_state=11
)
len(Y_train_1), Y_train_1.sum(), len(Y_test_1), Y_test_1.sum()
# Out:
# (258, 230, 87, 77)

# %% [markdown]
# ### Dokonuje sprawdzenia jakości pięciu klasyfikatorów takich jak :
#     1.KNeighborsClassifier
#     2.DecisionTreeClassifier
#     3.GradienBoostingClassifer
#     4.RandomForestClassifer
#     5.GausianNB
#     6.LogisticRegresion
#     7.MLPClassifer

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier

from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.model_selection import cross_val_score


models_1 = []
models_1.append(("KNN", KNeighborsClassifier(n_neighbors=3)))
models_1.append(("DSC", DecisionTreeClassifier(random_state=0, max_depth=2)))
models_1.append(
    (
        "GBC",
        GradientBoostingClassifier(
            n_estimators=100, learning_rate=1.0, max_depth=1, random_state=0
        ),
    )
)
models_1.append(("RFC", RandomForestClassifier(max_depth=2, random_state=0)))
models_1.append(("GNB", GaussianNB()))
models_1.append(("LR", LogisticRegression(random_state=0)))
models_1.append(("MLP", MLPClassifier(random_state=1, max_iter=300)))

# evaluate each model in turn
results = []
names = []
for name, model in models_1:
    kfold_1 = RepeatedStratifiedKFold(n_splits=2, n_repeats=2, random_state=0)
    cv_results_1 = cross_val_score(
        model, X_train_1, Y_train_1, cv=kfold_1, scoring="balanced_accuracy"
    )
    results.append(cv_results_1)
    names.append(name)
    msg = "%s: %.2f (%.3f)" % (name, cv_results_1.mean(), cv_results_1.std())
    print(msg)
# Out:
# KNN: 0.54 (0.041)
# DSC: 0.77 (0.119)
# GBC: 0.75 (0.089)
# RFC: 0.53 (0.022)
# GNB: 0.82 (0.054)
# LR: 0.70 (0.029)
# C:\Users\Marek\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Marek\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# ...

# %% [markdown]
# ### Losuje 20% wierszy z klasy decyzyjnej 0
# ### 20% = 76 wierszy

# %%
no_samples_2 = 76

# %%
random_slice_2 = data_decyz_0.sample(n=no_samples_2, random_state=0)
merge_data_2 = pd.merge(random_slice_2, data_decyz_1, how="outer")
merge_data_2
# Out:
#      A1     A2     A3  A4  A5  A6     A7  A8  A9  A10  A11  A12  A13  A14  \
# 0     0  26.17   2.00   2   5   3  0.000   0   0    0    1    2  276    2
# 1     1  20.00   7.00   2   8   4  0.500   0   0    0    0    2    0    1
# 2     1  19.42   1.50   1  13   4  2.000   1   0    0    1    2  100   21
# 3     0  18.17  10.00   1  11   8  0.165   0   0    0    0    2  340    1
# 4     1  34.00   4.50   2   6   4  1.000   1   0    0    1    2  240    1
# ..   ..    ...    ...  ..  ..  ..    ...  ..  ..  ...  ...  ...  ...  ...
# 378   1  43.00   0.29   1  13   8  1.750   1   1    8    0    2  100  376
# 379   1  31.57  10.50   2  14   4  6.500   1   0    0    0    2    0    1
# 380   0  18.83   9.54   2   6   4  0.085   1   0    0    0    2  100    1
# 381   0  27.42  14.50   2  14   8  3.085   1   1    1    0    2  120   12
# 382   1  41.00   0.04   2  10   4  0.040   0   1    1    0    1  560    1
#
#      Class
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
# ...

# %%
merge_data_2["Class"].value_counts()
# Out:
# 1    307
# 0     76
# Name: Class, dtype: int64

# %% [markdown]
# ### Przygotowuję dane do klasyfikacjii

# %%
dataset_2 = merge_data_2
dataset_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 383 entries, 0 to 382
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A1      383 non-null    int64
#  1   A2      383 non-null    float64
#  2   A3      383 non-null    float64
#  3   A4      383 non-null    int64
#  4   A5      383 non-null    int64
#  5   A6      383 non-null    int64
#  6   A7      383 non-null    float64
#  7   A8      383 non-null    int64
#  8   A9      383 non-null    int64
#  9   A10     383 non-null    int64
#  10  A11     383 non-null    int64
#  11  A12     383 non-null    int64
#  12  A13     383 non-null    int64
#  13  A14     383 non-null    int64
#  14  Class   383 non-null    int64
# dtypes: float64(3), int64(12)
# memory usage: 47.9 KB

# %%
X_2 = dataset_2.iloc[:, 0:14]
X_2 = X_2.values
Y_2 = dataset_2.iloc[:, -1].values
from sklearn.model_selection import train_test_split

X_train_2, X_test_2, Y_train_2, Y_test_2 = train_test_split(
    X_2, Y_2, test_size=0.25, stratify=Y_2, random_state=11
)
len(Y_train_2), Y_train_2.sum(), len(Y_test_2), Y_test_2.sum()
# Out:
# (287, 230, 96, 77)

# %% [markdown]
# ### Dokonuje sprawdzenia jakości pięciu klasyfikatorów takich jak :
#     1.LogisticRegression
#     2.LinearDiscriminantAnalysis
#     3.DecisionTreeClassifier
#     4.KNeighborsClassifier
#     5.SVC(Support Vector Classification)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.model_selection import cross_val_score

# from sklearn.metrics import roc_auc_score

models_2 = []
models_2.append(("LR", LogisticRegression(solver="lbfgs", max_iter=3000)))
models_2.append(("LDA", LinearDiscriminantAnalysis()))
models_2.append(("KNN", KNeighborsClassifier()))
models_2.append(("DSC", DecisionTreeClassifier(random_state=1, max_depth=2)))
models_2.append(("SVM", SVC()))

# evaluate each model in turn
results = []
names = []
for name, model in models_2:
    kfold_2 = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
    cv_results_2 = cross_val_score(
        model, X_train_2, Y_train_2, cv=kfold_2, scoring="balanced_accuracy"
    )
    results.append(cv_results_2)
    names.append(name)
    msg = "%s: %.2f (%.3f)" % (name, cv_results_2.mean(), cv_results_2.std())
    print(msg)
# Out:
# LR: 0.78 (0.111)
# LDA: 0.82 (0.102)
# KNN: 0.60 (0.110)
# DSC: 0.79 (0.124)
# SVM: 0.50 (0.000)

# %% [markdown]
# ### Losujes 30% wierszy  z klasy decyzyjnej 0
# ### 30% = 114 wierszy

# %%
no_samples_3 = 114

# %%
random_slice_3 = data_decyz_0.sample(n=no_samples_3, random_state=0)
merge_data_3 = pd.merge(random_slice_3, data_decyz_1, how="outer")
merge_data_3
# Out:
#      A1     A2     A3  A4  A5  A6     A7  A8  A9  A10  A11  A12  A13  A14  \
# 0     0  26.17   2.00   2   5   3  0.000   0   0    0    1    2  276    2
# 1     1  20.00   7.00   2   8   4  0.500   0   0    0    0    2    0    1
# 2     1  19.42   1.50   1  13   4  2.000   1   0    0    1    2  100   21
# 3     0  18.17  10.00   1  11   8  0.165   0   0    0    0    2  340    1
# 4     1  34.00   4.50   2   6   4  1.000   1   0    0    1    2  240    1
# ..   ..    ...    ...  ..  ..  ..    ...  ..  ..  ...  ...  ...  ...  ...
# 416   1  43.00   0.29   1  13   8  1.750   1   1    8    0    2  100  376
# 417   1  31.57  10.50   2  14   4  6.500   1   0    0    0    2    0    1
# 418   0  18.83   9.54   2   6   4  0.085   1   0    0    0    2  100    1
# 419   0  27.42  14.50   2  14   8  3.085   1   1    1    0    2  120   12
# 420   1  41.00   0.04   2  10   4  0.040   0   1    1    0    1  560    1
#
#      Class
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
# ...

# %%
merge_data_3["Class"].value_counts()
# Out:
# 1    307
# 0    114
# Name: Class, dtype: int64

# %% [markdown]
# ### Przygotowuję dane do klasyfikacjii

# %%
dataset_3 = merge_data_3
dataset_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 421 entries, 0 to 420
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A1      421 non-null    int64
#  1   A2      421 non-null    float64
#  2   A3      421 non-null    float64
#  3   A4      421 non-null    int64
#  4   A5      421 non-null    int64
#  5   A6      421 non-null    int64
#  6   A7      421 non-null    float64
#  7   A8      421 non-null    int64
#  8   A9      421 non-null    int64
#  9   A10     421 non-null    int64
#  10  A11     421 non-null    int64
#  11  A12     421 non-null    int64
#  12  A13     421 non-null    int64
#  13  A14     421 non-null    int64
#  14  Class   421 non-null    int64
# dtypes: float64(3), int64(12)
# memory usage: 52.6 KB

# %%
X_3 = dataset_3.iloc[:, 0:14]
X_3 = X_3.values
Y_3 = dataset_3.iloc[:, -1].values
from sklearn.model_selection import train_test_split

X_train_3, X_test_3, Y_train_3, Y_test_3 = train_test_split(
    X_3, Y_3, test_size=0.25, stratify=Y_3, random_state=11
)
len(Y_train_3), Y_train_3.sum(), len(Y_test_3), Y_test_3.sum()
# Out:
# (315, 230, 106, 77)

# %% [markdown]
# ### Dokonuje sprawdzenia jakości pięciu klasyfikatorów takich jak :
#     1.LogisticRegression
#     2.LinearDiscriminantAnalysis
#     3.DecisionTreeClassifier
#     4.KNeighborsClassifier
#     5.SVC(Support Vector Classification)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.model_selection import cross_val_score

# from sklearn.metrics import roc_auc_score

models_3 = []
models_3.append(("LR", LogisticRegression(solver="lbfgs", max_iter=3000)))
models_3.append(("LDA", LinearDiscriminantAnalysis()))
models_3.append(("KNN", KNeighborsClassifier()))
models_3.append(("DSC", DecisionTreeClassifier(random_state=1, max_depth=2)))
models_3.append(("SVM", SVC()))

# evaluate each model in turn
results = []
names = []
for name, model in models_3:
    kfold_3 = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
    cv_results_3 = cross_val_score(
        model, X_train_3, Y_train_3, cv=kfold_3, scoring="balanced_accuracy"
    )
    results.append(cv_results_3)
    names.append(name)
    msg = "%s: %.2f (%.3f)" % (name, cv_results_3.mean(), cv_results_3.std())
    print(msg)
# Out:
# LR: 0.84 (0.072)
# LDA: 0.86 (0.069)
# KNN: 0.62 (0.095)
# DSC: 0.85 (0.069)
# SVM: 0.50 (0.000)

# %% [markdown]
# ### Losuje 40% wierszy z klasy decyzyjnej 0
# ### 40% = 153 wierszy

# %%
no_samples_4 = 153

# %%
random_slice_4 = data_decyz_0.sample(n=no_samples_4, random_state=0)
merge_data_4 = pd.merge(random_slice_4, data_decyz_1, how="outer")
merge_data_4
# Out:
#      A1     A2     A3  A4  A5  A6     A7  A8  A9  A10  A11  A12  A13  A14  \
# 0     0  26.17   2.00   2   5   3  0.000   0   0    0    1    2  276    2
# 1     1  20.00   7.00   2   8   4  0.500   0   0    0    0    2    0    1
# 2     1  19.42   1.50   1  13   4  2.000   1   0    0    1    2  100   21
# 3     0  18.17  10.00   1  11   8  0.165   0   0    0    0    2  340    1
# 4     1  34.00   4.50   2   6   4  1.000   1   0    0    1    2  240    1
# ..   ..    ...    ...  ..  ..  ..    ...  ..  ..  ...  ...  ...  ...  ...
# 455   1  43.00   0.29   1  13   8  1.750   1   1    8    0    2  100  376
# 456   1  31.57  10.50   2  14   4  6.500   1   0    0    0    2    0    1
# 457   0  18.83   9.54   2   6   4  0.085   1   0    0    0    2  100    1
# 458   0  27.42  14.50   2  14   8  3.085   1   1    1    0    2  120   12
# 459   1  41.00   0.04   2  10   4  0.040   0   1    1    0    1  560    1
#
#      Class
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
# ...

# %%
merge_data_4["Class"].value_counts()
# Out:
# 1    307
# 0    153
# Name: Class, dtype: int64

# %% [markdown]
# ### Przygotowuje dane do klasyfikacjii

# %%
dataset_4 = merge_data_4
dataset_4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 460 entries, 0 to 459
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A1      460 non-null    int64
#  1   A2      460 non-null    float64
#  2   A3      460 non-null    float64
#  3   A4      460 non-null    int64
#  4   A5      460 non-null    int64
#  5   A6      460 non-null    int64
#  6   A7      460 non-null    float64
#  7   A8      460 non-null    int64
#  8   A9      460 non-null    int64
#  9   A10     460 non-null    int64
#  10  A11     460 non-null    int64
#  11  A12     460 non-null    int64
#  12  A13     460 non-null    int64
#  13  A14     460 non-null    int64
#  14  Class   460 non-null    int64
# dtypes: float64(3), int64(12)
# memory usage: 57.5 KB

# %%
X_4 = dataset_4.iloc[:, 0:14]
X_4 = X_4.values
Y_4 = dataset_4.iloc[:, -1].values
from sklearn.model_selection import train_test_split

X_train_4, X_test_4, Y_train_4, Y_test_4 = train_test_split(
    X_4, Y_4, test_size=0.25, stratify=Y_4, random_state=11
)
len(Y_train_4), Y_train_4.sum(), len(Y_test_4), Y_test_4.sum()
# Out:
# (345, 230, 115, 77)

# %% [markdown]
# ### Dokonuje sprawdzenia jakości pięciu klasyfikatorów takich jak :
#     1.LogisticRegression
#     2.LinearDiscriminantAnalysis
#     3.DecisionTreeClassifier
#     4.KNeighborsClassifier
#     5.SVC(Support Vector Classification)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.model_selection import cross_val_score

# from sklearn.metrics import roc_auc_score

models_4 = []
models_4.append(("LR", LogisticRegression(solver="lbfgs", max_iter=3000)))
models_4.append(("LDA", LinearDiscriminantAnalysis()))
models_4.append(("KNN", KNeighborsClassifier()))
models_4.append(("DSC", DecisionTreeClassifier(random_state=1, max_depth=2)))
models_4.append(("SVM", SVC()))

# evaluate each model in turn
results = []
names = []
for name, model in models_4:
    kfold_4 = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
    cv_results_4 = cross_val_score(
        model, X_train_4, Y_train_4, cv=kfold_4, scoring="balanced_accuracy"
    )
    results.append(cv_results_4)
    names.append(name)
    msg = "%s: %.2f (%.3f)" % (name, cv_results_4.mean(), cv_results_4.std())
    print(msg)
# Out:
# LR: 0.84 (0.077)
# LDA: 0.85 (0.076)
# KNN: 0.62 (0.088)
# DSC: 0.86 (0.075)
# SVM: 0.50 (0.000)

# %% [markdown]
# ### Losuje 50% wierszy z klasy decyzyjnej 0
# ### 50% = 191 wierszy

# %%
no_samples_5 = 191

# %%
random_slice_5 = data_decyz_0.sample(n=no_samples_5, random_state=0)
merge_data_5 = pd.merge(random_slice_5, data_decyz_1, how="outer")
merge_data_5
# Out:
#      A1     A2     A3  A4  A5  A6     A7  A8  A9  A10  A11  A12  A13  A14  \
# 0     0  26.17   2.00   2   5   3  0.000   0   0    0    1    2  276    2
# 1     1  20.00   7.00   2   8   4  0.500   0   0    0    0    2    0    1
# 2     1  19.42   1.50   1  13   4  2.000   1   0    0    1    2  100   21
# 3     0  18.17  10.00   1  11   8  0.165   0   0    0    0    2  340    1
# 4     1  34.00   4.50   2   6   4  1.000   1   0    0    1    2  240    1
# ..   ..    ...    ...  ..  ..  ..    ...  ..  ..  ...  ...  ...  ...  ...
# 493   1  43.00   0.29   1  13   8  1.750   1   1    8    0    2  100  376
# 494   1  31.57  10.50   2  14   4  6.500   1   0    0    0    2    0    1
# 495   0  18.83   9.54   2   6   4  0.085   1   0    0    0    2  100    1
# 496   0  27.42  14.50   2  14   8  3.085   1   1    1    0    2  120   12
# 497   1  41.00   0.04   2  10   4  0.040   0   1    1    0    1  560    1
#
#      Class
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
# ...

# %%
merge_data_5["Class"].value_counts()
# Out:
# 1    307
# 0    191
# Name: Class, dtype: int64

# %% [markdown]
# ### Przygotowuję dane do klasyfikacjii

# %%
dataset_5 = merge_data_5
dataset_5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 498 entries, 0 to 497
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A1      498 non-null    int64
#  1   A2      498 non-null    float64
#  2   A3      498 non-null    float64
#  3   A4      498 non-null    int64
#  4   A5      498 non-null    int64
#  5   A6      498 non-null    int64
#  6   A7      498 non-null    float64
#  7   A8      498 non-null    int64
#  8   A9      498 non-null    int64
#  9   A10     498 non-null    int64
#  10  A11     498 non-null    int64
#  11  A12     498 non-null    int64
#  12  A13     498 non-null    int64
#  13  A14     498 non-null    int64
#  14  Class   498 non-null    int64
# dtypes: float64(3), int64(12)
# memory usage: 62.2 KB

# %%
X_5 = dataset_5.iloc[:, 0:14]
X_5 = X_5.values
Y_5 = dataset_5.iloc[:, -1].values
from sklearn.model_selection import train_test_split

X_train_5, X_test_5, Y_train_5, Y_test_5 = train_test_split(
    X_5, Y_5, test_size=0.25, stratify=Y_5, random_state=11
)
len(Y_train_5), Y_train_5.sum(), len(Y_test_5), Y_test_5.sum()
# Out:
# (373, 230, 125, 77)

# %% [markdown]
# ### Dokonuje sprawdzenia jakości pięciu klasyfikatorów takich jak :
#     1.LogisticRegression
#     2.LinearDiscriminantAnalysis
#     3.DecisionTreeClassifier
#     4.KNeighborsClassifier
#     5.SVC(Support Vector Classification)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.model_selection import cross_val_score

# from sklearn.metrics import roc_auc_score

models_5 = []
models_5.append(("LR", LogisticRegression(solver="lbfgs", max_iter=3000)))
models_5.append(("LDA", LinearDiscriminantAnalysis()))
models_5.append(("KNN", KNeighborsClassifier()))
models_5.append(("DSC", DecisionTreeClassifier(random_state=1, max_depth=2)))
models_5.append(("SVM", SVC()))

# evaluate each model in turn
results = []
names = []
for name, model in models_5:
    kfold_5 = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
    cv_results_5 = cross_val_score(
        model, X_train_5, Y_train_5, cv=kfold_5, scoring="balanced_accuracy"
    )
    results.append(cv_results_5)
    names.append(name)
    msg = "%s: %.2f (%.3f)" % (name, cv_results_5.mean(), cv_results_5.std())
    print(msg)
# Out:
# LR: 0.84 (0.054)
# LDA: 0.85 (0.051)
# KNN: 0.63 (0.062)
# DSC: 0.86 (0.049)
# SVM: 0.50 (0.000)

# %% [markdown]
# ### Losuje 60% wierszy z klasy decyzyjnej 0
# ### 60% = 229 wierszy

# %%
no_samples_6 = 229

# %%
random_slice_6 = data_decyz_0.sample(n=no_samples_6, random_state=0)
merge_data_6 = pd.merge(random_slice_6, data_decyz_1, how="outer")
merge_data_6
# Out:
#      A1     A2     A3  A4  A5  A6     A7  A8  A9  A10  A11  A12  A13  A14  \
# 0     0  26.17   2.00   2   5   3  0.000   0   0    0    1    2  276    2
# 1     1  20.00   7.00   2   8   4  0.500   0   0    0    0    2    0    1
# 2     1  19.42   1.50   1  13   4  2.000   1   0    0    1    2  100   21
# 3     0  18.17  10.00   1  11   8  0.165   0   0    0    0    2  340    1
# 4     1  34.00   4.50   2   6   4  1.000   1   0    0    1    2  240    1
# ..   ..    ...    ...  ..  ..  ..    ...  ..  ..  ...  ...  ...  ...  ...
# 531   1  43.00   0.29   1  13   8  1.750   1   1    8    0    2  100  376
# 532   1  31.57  10.50   2  14   4  6.500   1   0    0    0    2    0    1
# 533   0  18.83   9.54   2   6   4  0.085   1   0    0    0    2  100    1
# 534   0  27.42  14.50   2  14   8  3.085   1   1    1    0    2  120   12
# 535   1  41.00   0.04   2  10   4  0.040   0   1    1    0    1  560    1
#
#      Class
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
# ...

# %%
merge_data_6["Class"].value_counts()
# Out:
# 1    307
# 0    229
# Name: Class, dtype: int64

# %% [markdown]
# ### Przygotowuje dane do klasyfikacjii

# %%
dataset_6 = merge_data_6
dataset_6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 536 entries, 0 to 535
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A1      536 non-null    int64
#  1   A2      536 non-null    float64
#  2   A3      536 non-null    float64
#  3   A4      536 non-null    int64
#  4   A5      536 non-null    int64
#  5   A6      536 non-null    int64
#  6   A7      536 non-null    float64
#  7   A8      536 non-null    int64
#  8   A9      536 non-null    int64
#  9   A10     536 non-null    int64
#  10  A11     536 non-null    int64
#  11  A12     536 non-null    int64
#  12  A13     536 non-null    int64
#  13  A14     536 non-null    int64
#  14  Class   536 non-null    int64
# dtypes: float64(3), int64(12)
# memory usage: 67.0 KB

# %%
X_6 = dataset_6.iloc[:, 0:14]
X_6 = X_6.values
Y_6 = dataset_6.iloc[:, -1].values
from sklearn.model_selection import train_test_split

X_train_6, X_test_6, Y_train_6, Y_test_6 = train_test_split(
    X_6, Y_6, test_size=0.25, stratify=Y_6, random_state=11
)
len(Y_train_6), Y_train_6.sum(), len(Y_test_6), Y_test_6.sum()
# Out:
# (402, 230, 134, 77)

# %% [markdown]
# ### Dokonuje sprawdzenia jakości pięciu klasyfikatorów takich jak :
#     1.LogisticRegression
#     2.LinearDiscriminantAnalysis
#     3.DecisionTreeClassifier
#     4.KNeighborsClassifier
#     5.SVC(Support Vector Classification)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.model_selection import cross_val_score

# from sklearn.metrics import roc_auc_score

models_6 = []
models_6.append(("LR", LogisticRegression(solver="lbfgs", max_iter=3000)))
models_6.append(("LDA", LinearDiscriminantAnalysis()))
models_6.append(("KNN", KNeighborsClassifier()))
models_6.append(("DSC", DecisionTreeClassifier(random_state=1, max_depth=2)))
models_6.append(("SVM", SVC()))

# evaluate each model in turn
results = []
names = []
for name, model in models_6:
    kfold_6 = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
    cv_results_6 = cross_val_score(
        model, X_train_6, Y_train_6, cv=kfold_6, scoring="balanced_accuracy"
    )
    results.append(cv_results_6)
    names.append(name)
    msg = "%s: %.2f (%.3f)" % (name, cv_results_6.mean(), cv_results_6.std())
    print(msg)
# Out:
# LR: 0.85 (0.047)
# LDA: 0.84 (0.042)
# KNN: 0.65 (0.070)
# DSC: 0.84 (0.048)
# SVM: 0.55 (0.056)

# %%
from sklearn.metrics import balanced_accuracy_score

# %% [markdown]
# # Sprawdzam jakość pięciu klasyfikatorów na orginalnych danych

# %%
data.shape
# Out:
# (690, 15)

# %%
dataset_orig = data
X = dataset_orig.iloc[:,0:14]
# X= pd.get_dummies(X)
X=X.values
Y=dataset_orig.iloc[:,-1].values
from sklearn.model_selection import train_test_split

# %%
X.shape, Y.shape
# Out:
# ((690, 14), (690,))

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.model_selection import cross_val_score

models = []
models.append(("LR", LogisticRegression(solver="lbfgs", max_iter=3000)))
models.append(("LDA", LinearDiscriminantAnalysis()))
models.append(("KNN", KNeighborsClassifier()))
models.append(("DSC", DecisionTreeClassifier(random_state=1, max_depth=2)))
models.append(("SVM", SVC()))
# evaluate each model in turn
results = []
names = []
for name, model in models:
    kfold = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
    cv_results = cross_val_score(model, X, Y, cv=kfold, scoring="balanced_accuracy")
    results.append(cv_results)
    names.append(name)
    msg = "%s: %.2f (%.3f)" % (name, cv_results.mean(), cv_results.std())
    print(msg)
# Out:
# LR: 0.86 (0.035)
# LDA: 0.86 (0.035)
# KNN: 0.68 (0.066)
# DSC: 0.86 (0.034)
# SVM: 0.62 (0.044)

# %% [markdown]
# # Dokonuje poprawy jakośći klasyfikatorów przy użyciu metody Under-sampling

# %% [markdown]
# ### Dla pierwszego zbioru (10%)

# %%
x_undsamp_1 = merge_data_1.drop(["Class"], axis=1)
x_undsamp_1
# Out:
#      A1     A2     A3  A4  A5  A6     A7  A8  A9  A10  A11  A12  A13  A14
# 0     0  26.17   2.00   2   5   3  0.000   0   0    0    1    2  276    2
# 1     1  20.00   7.00   2   8   4  0.500   0   0    0    0    2    0    1
# 2     1  19.42   1.50   1  13   4  2.000   1   0    0    1    2  100   21
# 3     0  18.17  10.00   1  11   8  0.165   0   0    0    0    2  340    1
# 4     1  34.00   4.50   2   6   4  1.000   1   0    0    1    2  240    1
# ..   ..    ...    ...  ..  ..  ..    ...  ..  ..  ...  ...  ...  ...  ...
# 340   1  43.00   0.29   1  13   8  1.750   1   1    8    0    2  100  376
# 341   1  31.57  10.50   2  14   4  6.500   1   0    0    0    2    0    1
# 342   0  18.83   9.54   2   6   4  0.085   1   0    0    0    2  100    1
# 343   0  27.42  14.50   2  14   8  3.085   1   1    1    0    2  120   12
# 344   1  41.00   0.04   2  10   4  0.040   0   1    1    0    1  560    1
#
# [345 rows x 14 columns]

# %%
y_undsamp_1 = merge_data_1["Class"]
y_undsamp_1
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 340    1
# 341    1
# 342    1
# 343    1
# 344    1
# Name: Class, Length: 345, dtype: int64

# %%
y_undsamp_1.value_counts()
# Out:
# 1    307
# 0     38
# Name: Class, dtype: int64

# %%
import matplotlib.pyplot as plt
from matplotlib.figure import Figure

fig_1 = plt.figure(figsize=(4, 4))
fig_1.suptitle("Original Data")
chart_1 = y_undsamp_1.value_counts()
labels_class = ["1", "0"]
plt.pie(chart_1, autopct="%.2f", labels=labels_class)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="400">

# %%
from imblearn.under_sampling import RandomUnderSampler

rus_1 = RandomUnderSampler(sampling_strategy=1)
X_res_1, y_res_1 = rus_1.fit_resample(x_undsamp_1, y_undsamp_1)
fig_2 = plt.figure(figsize=(4, 4))

plt.pie(y_res_1.value_counts(), autopct="%.2f", labels=labels_class)
plt.title("Under-sampling")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="400">

# %%
y_res_1.value_counts()
# Out:
# 0    38
# 1    38
# Name: Class, dtype: int64

# %% [markdown]
# ### Dokonuje sprawdzenia jakości pięciu klasyfikatorów po zastosowaniu metody under_sampling takich jak :
#     1.LogisticRegression
#     2.LinearDiscriminantAnalysis
#     3.DecisionTreeClassifier
#     4.KNeighborsClassifier
#     5.SVC(Support Vector Classification)

# %%
models_undsamp_1 = []
models_undsamp_1.append(("LR", LogisticRegression(solver="lbfgs", max_iter=3000)))
models_undsamp_1.append(("LDA", LinearDiscriminantAnalysis()))
models_undsamp_1.append(("KNN", KNeighborsClassifier()))
models_undsamp_1.append(("DSC", DecisionTreeClassifier(random_state=1, max_depth=2)))
models_undsamp_1.append(("SVM", SVC()))
# evaluate each model in turn
results_undsamp = []
names_undsamp = []
for name, model in models_undsamp_1:
    kfold = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
    cv_results = cross_val_score(
        model, X_res_1, y_res_1, cv=kfold, scoring="balanced_accuracy"
    )
    results.append(cv_results)
    names.append(name)
    msg = "%s: %.2f (%.3f)" % (name, cv_results.mean(), cv_results.std())
    print(msg)
# Out:
# LR: 0.74 (0.167)
# LDA: 0.80 (0.120)
# KNN: 0.53 (0.169)
# DSC: 0.86 (0.105)
# SVM: 0.60 (0.131)

# %% [markdown]
# ### Dla drugiego zbioru (20%)

# %%
x_undsamp_2 = merge_data_2.drop(["Class"], axis=1)
x_undsamp_2
# Out:
#      A1     A2     A3  A4  A5  A6     A7  A8  A9  A10  A11  A12  A13  A14
# 0     0  26.17   2.00   2   5   3  0.000   0   0    0    1    2  276    2
# 1     1  20.00   7.00   2   8   4  0.500   0   0    0    0    2    0    1
# 2     1  19.42   1.50   1  13   4  2.000   1   0    0    1    2  100   21
# 3     0  18.17  10.00   1  11   8  0.165   0   0    0    0    2  340    1
# 4     1  34.00   4.50   2   6   4  1.000   1   0    0    1    2  240    1
# ..   ..    ...    ...  ..  ..  ..    ...  ..  ..  ...  ...  ...  ...  ...
# 378   1  43.00   0.29   1  13   8  1.750   1   1    8    0    2  100  376
# 379   1  31.57  10.50   2  14   4  6.500   1   0    0    0    2    0    1
# 380   0  18.83   9.54   2   6   4  0.085   1   0    0    0    2  100    1
# 381   0  27.42  14.50   2  14   8  3.085   1   1    1    0    2  120   12
# 382   1  41.00   0.04   2  10   4  0.040   0   1    1    0    1  560    1
#
# [383 rows x 14 columns]

# %%
y_undsamp_2 = merge_data_2["Class"]
y_undsamp_2
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 378    1
# 379    1
# 380    1
# 381    1
# 382    1
# Name: Class, Length: 383, dtype: int64

# %%
y_undsamp_2.value_counts()
# Out:
# 1    307
# 0     76
# Name: Class, dtype: int64

# %%
import matplotlib.pyplot as plt
from matplotlib.figure import Figure

fig_2 = plt.figure(figsize=(4, 4))
fig_2.suptitle("Original Data")
chart_2 = y_undsamp_2.value_counts()
labels_class = ["1", "0"]
plt.pie(chart_2, autopct="%.2f", labels=labels_class)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="400">

# %%
from imblearn.under_sampling import RandomUnderSampler

rus_2 = RandomUnderSampler(sampling_strategy=1)
X_res_2, y_res_2 = rus_2.fit_resample(x_undsamp_2, y_undsamp_2)
fig_2 = plt.figure(figsize=(4, 4))

plt.pie(y_res_2.value_counts(), autopct="%.2f", labels=labels_class)
plt.title("Under-sampling")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="400">

# %%
y_res_2.value_counts()
# Out:
# 0    76
# 1    76
# Name: Class, dtype: int64

# %% [markdown]
# ## Dokonuje sprawdzenia jakości pięciu klasyfikatorów po zastosowaniu metody Under-Sampling

# %%
models_undsamp_2 = []
models_undsamp_2.append(("LR", LogisticRegression(solver="lbfgs", max_iter=3000)))
models_undsamp_2.append(("LDA", LinearDiscriminantAnalysis()))
models_undsamp_2.append(("KNN", KNeighborsClassifier()))
models_undsamp_2.append(("DSC", DecisionTreeClassifier(random_state=1, max_depth=2)))
models_undsamp_2.append(("SVM", SVC()))
# evaluate each model in turn
results_undsamp = []
names_undsamp = []
for name, model in models_undsamp_2:
    kfold = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
    cv_results = cross_val_score(
        model, X_res_2, y_res_2, cv=kfold, scoring="balanced_accuracy"
    )
    results.append(cv_results)
    names.append(name)
    msg = "%s: %.2f (%.3f)" % (name, cv_results.mean(), cv_results.std())
    print(msg)
# Out:
# LR: 0.82 (0.090)
# LDA: 0.84 (0.086)
# KNN: 0.70 (0.120)
# DSC: 0.80 (0.085)
# SVM: 0.60 (0.086)

# %% [markdown]
# ### Dla trzeciego zbioru (30%)

# %%
x_undsamp_3 = merge_data_3.drop(["Class"], axis=1)
x_undsamp_3
# Out:
#      A1     A2     A3  A4  A5  A6     A7  A8  A9  A10  A11  A12  A13  A14
# 0     0  26.17   2.00   2   5   3  0.000   0   0    0    1    2  276    2
# 1     1  20.00   7.00   2   8   4  0.500   0   0    0    0    2    0    1
# 2     1  19.42   1.50   1  13   4  2.000   1   0    0    1    2  100   21
# 3     0  18.17  10.00   1  11   8  0.165   0   0    0    0    2  340    1
# 4     1  34.00   4.50   2   6   4  1.000   1   0    0    1    2  240    1
# ..   ..    ...    ...  ..  ..  ..    ...  ..  ..  ...  ...  ...  ...  ...
# 416   1  43.00   0.29   1  13   8  1.750   1   1    8    0    2  100  376
# 417   1  31.57  10.50   2  14   4  6.500   1   0    0    0    2    0    1
# 418   0  18.83   9.54   2   6   4  0.085   1   0    0    0    2  100    1
# 419   0  27.42  14.50   2  14   8  3.085   1   1    1    0    2  120   12
# 420   1  41.00   0.04   2  10   4  0.040   0   1    1    0    1  560    1
#
# [421 rows x 14 columns]

# %%
y_undsamp_3 = merge_data_3["Class"]
y_undsamp_3
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 416    1
# 417    1
# 418    1
# 419    1
# 420    1
# Name: Class, Length: 421, dtype: int64

# %%
y_undsamp_3.value_counts()
# Out:
# 1    307
# 0    114
# Name: Class, dtype: int64

# %%
import matplotlib.pyplot as plt
from matplotlib.figure import Figure

fig_3 = plt.figure(figsize=(4, 4))
fig_3.suptitle("Original Data")
chart_3 = y_undsamp_3.value_counts()
labels_class = ["1", "0"]
plt.pie(chart_3, autopct="%.2f", labels=labels_class)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="400">

# %%
from imblearn.under_sampling import RandomUnderSampler

rus_3 = RandomUnderSampler(sampling_strategy=1)
X_res_3, y_res_3 = rus_3.fit_resample(x_undsamp_3, y_undsamp_3)
fig_3 = plt.figure(figsize=(4, 4))

plt.pie(y_res_3.value_counts(), autopct="%.2f", labels=labels_class)
plt.title("Under-sampling")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="400">

# %%
y_res_3.value_counts()
# Out:
# 0    114
# 1    114
# Name: Class, dtype: int64

# %% [markdown]
# ## Dokonuje sprawdzenia jakości pięciu klasyfikatorów po zastosowaniu metody under_sampling takich jak :
#     1.LogisticRegression
#     2.LinearDiscriminantAnalysis
#     3.DecisionTreeClassifier
#     4.KNeighborsClassifier
#     5.SVC(Support Vector Classification)

# %%
models_undsamp_3 = []
models_undsamp_3.append(("LR", LogisticRegression(solver="lbfgs", max_iter=3000)))
models_undsamp_3.append(("LDA", LinearDiscriminantAnalysis()))
models_undsamp_3.append(("KNN", KNeighborsClassifier()))
models_undsamp_3.append(("DSC", DecisionTreeClassifier(random_state=1, max_depth=2)))
models_undsamp_3.append(("SVM", SVC()))
# evaluate each model in turn
results_undsamp = []
names_undsamp = []
for name, model in models_undsamp_3:
    kfold = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
    cv_results = cross_val_score(
        model, X_res_3, y_res_3, cv=kfold, scoring="balanced_accuracy"
    )
    results.append(cv_results)
    names.append(name)
    msg = "%s: %.2f (%.3f)" % (name, cv_results.mean(), cv_results.std())
    print(msg)
# Out:
# LR: 0.84 (0.075)
# LDA: 0.84 (0.061)
# KNN: 0.67 (0.100)
# DSC: 0.86 (0.056)
# SVM: 0.58 (0.076)

# %% [markdown]
# ### Dla czwartego zbioru (40%)

# %%
x_undsamp_4 = merge_data_4.drop(["Class"], axis=1)
x_undsamp_4
# Out:
#      A1     A2     A3  A4  A5  A6     A7  A8  A9  A10  A11  A12  A13  A14
# 0     0  26.17   2.00   2   5   3  0.000   0   0    0    1    2  276    2
# 1     1  20.00   7.00   2   8   4  0.500   0   0    0    0    2    0    1
# 2     1  19.42   1.50   1  13   4  2.000   1   0    0    1    2  100   21
# 3     0  18.17  10.00   1  11   8  0.165   0   0    0    0    2  340    1
# 4     1  34.00   4.50   2   6   4  1.000   1   0    0    1    2  240    1
# ..   ..    ...    ...  ..  ..  ..    ...  ..  ..  ...  ...  ...  ...  ...
# 455   1  43.00   0.29   1  13   8  1.750   1   1    8    0    2  100  376
# 456   1  31.57  10.50   2  14   4  6.500   1   0    0    0    2    0    1
# 457   0  18.83   9.54   2   6   4  0.085   1   0    0    0    2  100    1
# 458   0  27.42  14.50   2  14   8  3.085   1   1    1    0    2  120   12
# 459   1  41.00   0.04   2  10   4  0.040   0   1    1    0    1  560    1
#
# [460 rows x 14 columns]

# %%
y_undsamp_4 = merge_data_4["Class"]
y_undsamp_4
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 455    1
# 456    1
# 457    1
# 458    1
# 459    1
# Name: Class, Length: 460, dtype: int64

# %%
y_undsamp_4.value_counts()
# Out:
# 1    307
# 0    153
# Name: Class, dtype: int64

# %%
import matplotlib.pyplot as plt
from matplotlib.figure import Figure

fig_4 = plt.figure(figsize=(4, 4))
fig_4.suptitle("Original Data")
chart_4 = y_undsamp_4.value_counts()
labels_class = ["1", "0"]
plt.pie(chart_4, autopct="%.2f", labels=labels_class)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="400">

# %%
from imblearn.under_sampling import RandomUnderSampler

rus_4 = RandomUnderSampler(sampling_strategy=1)
X_res_4, y_res_4 = rus_4.fit_resample(x_undsamp_4, y_undsamp_4)
fig_4 = plt.figure(figsize=(4, 4))

plt.pie(y_res_4.value_counts(), autopct="%.2f", labels=labels_class)
plt.title("Under-sampling")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="400">

# %%
y_res_4.value_counts()
# Out:
# 0    153
# 1    153
# Name: Class, dtype: int64

# %% [markdown]
# ## Dokonuje sprawdzenia jakości pięciu klasyfikatorów po zastosowaniu metody under_sampling takich jak :
#     1.LogisticRegression
#     2.LinearDiscriminantAnalysis
#     3.DecisionTreeClassifier
#     4.KNeighborsClassifier
#     5.SVC(Support Vector Classification)

# %%
models_undsamp_4 = []
models_undsamp_4.append(("LR", LogisticRegression(solver="lbfgs", max_iter=3000)))
models_undsamp_4.append(("LDA", LinearDiscriminantAnalysis()))
models_undsamp_4.append(("KNN", KNeighborsClassifier()))
models_undsamp_4.append(("DSC", DecisionTreeClassifier(random_state=1, max_depth=2)))
models_undsamp_4.append(("SVM", SVC()))
# evaluate each model in turn
results_undsamp = []
names_undsamp = []
for name, model in models_undsamp_4:
    kfold = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
    cv_results = cross_val_score(
        model, X_res_4, y_res_4, cv=kfold, scoring="balanced_accuracy"
    )
    results.append(cv_results)
    names.append(name)
    msg = "%s: %.2f (%.3f)" % (name, cv_results.mean(), cv_results.std())
    print(msg)
# Out:
# LR: 0.85 (0.064)
# LDA: 0.84 (0.058)
# KNN: 0.67 (0.078)
# DSC: 0.84 (0.056)
# SVM: 0.61 (0.053)

# %% [markdown]
# ### Dla piątego zbioru (50%)

# %%
x_undsamp_5 = merge_data_5.drop(["Class"], axis=1)
x_undsamp_5
# Out:
#      A1     A2     A3  A4  A5  A6     A7  A8  A9  A10  A11  A12  A13  A14
# 0     0  26.17   2.00   2   5   3  0.000   0   0    0    1    2  276    2
# 1     1  20.00   7.00   2   8   4  0.500   0   0    0    0    2    0    1
# 2     1  19.42   1.50   1  13   4  2.000   1   0    0    1    2  100   21
# 3     0  18.17  10.00   1  11   8  0.165   0   0    0    0    2  340    1
# 4     1  34.00   4.50   2   6   4  1.000   1   0    0    1    2  240    1
# ..   ..    ...    ...  ..  ..  ..    ...  ..  ..  ...  ...  ...  ...  ...
# 493   1  43.00   0.29   1  13   8  1.750   1   1    8    0    2  100  376
# 494   1  31.57  10.50   2  14   4  6.500   1   0    0    0    2    0    1
# 495   0  18.83   9.54   2   6   4  0.085   1   0    0    0    2  100    1
# 496   0  27.42  14.50   2  14   8  3.085   1   1    1    0    2  120   12
# 497   1  41.00   0.04   2  10   4  0.040   0   1    1    0    1  560    1
#
# [498 rows x 14 columns]

# %%
y_undsamp_5 = merge_data_5["Class"]
y_undsamp_5
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 493    1
# 494    1
# 495    1
# 496    1
# 497    1
# Name: Class, Length: 498, dtype: int64

# %%
y_undsamp_5.value_counts()
# Out:
# 1    307
# 0    191
# Name: Class, dtype: int64

# %%
import matplotlib.pyplot as plt
from matplotlib.figure import Figure

fig_5 = plt.figure(figsize=(4, 4))
fig_5.suptitle("Original Data")
chart_5 = y_undsamp_5.value_counts()
labels_class = ["1", "0"]
plt.pie(chart_5, autopct="%.2f", labels=labels_class)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="400">

# %%
from imblearn.under_sampling import RandomUnderSampler

rus_5 = RandomUnderSampler(sampling_strategy=1)
X_res_5, y_res_5 = rus_5.fit_resample(x_undsamp_5, y_undsamp_5)
fig_5 = plt.figure(figsize=(4, 4))

plt.pie(y_res_5.value_counts(), autopct="%.2f", labels=labels_class)
plt.title("Under-sampling")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="400">

# %%
y_res_5.value_counts()
# Out:
# 0    191
# 1    191
# Name: Class, dtype: int64

# %% [markdown]
# ## Dokonuje sprawdzenia jakości pięciu klasyfikatorów po zastosowaniu metody under_sampling takich jak :
#     1.LogisticRegression
#     2.LinearDiscriminantAnalysis
#     3.DecisionTreeClassifier
#     4.KNeighborsClassifier
#     5.SVC(Support Vector Classification)

# %%
models_undsamp_5 = []
models_undsamp_5.append(("LR", LogisticRegression(solver="lbfgs", max_iter=3000)))
models_undsamp_5.append(("LDA", LinearDiscriminantAnalysis()))
models_undsamp_5.append(("KNN", KNeighborsClassifier()))
models_undsamp_5.append(("DSC", DecisionTreeClassifier(random_state=1, max_depth=2)))
models_undsamp_5.append(("SVM", SVC()))
# evaluate each model in turn
results_undsamp = []
names_undsamp = []
for name, model in models_undsamp_5:
    kfold = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
    cv_results = cross_val_score(
        model, X_res_5, y_res_5, cv=kfold, scoring="balanced_accuracy"
    )
    results.append(cv_results)
    names.append(name)
    msg = "%s: %.2f (%.3f)" % (name, cv_results.mean(), cv_results.std())
    print(msg)
# Out:
# LR: 0.87 (0.050)
# LDA: 0.86 (0.047)
# KNN: 0.67 (0.079)
# DSC: 0.86 (0.045)
# SVM: 0.63 (0.067)

# %% [markdown]
# ### Dla szóstego zbioru (60%)

# %%
x_undsamp_6 = merge_data_6.drop(["Class"], axis=1)
x_undsamp_6
# Out:
#      A1     A2     A3  A4  A5  A6     A7  A8  A9  A10  A11  A12  A13  A14
# 0     0  26.17   2.00   2   5   3  0.000   0   0    0    1    2  276    2
# 1     1  20.00   7.00   2   8   4  0.500   0   0    0    0    2    0    1
# 2     1  19.42   1.50   1  13   4  2.000   1   0    0    1    2  100   21
# 3     0  18.17  10.00   1  11   8  0.165   0   0    0    0    2  340    1
# 4     1  34.00   4.50   2   6   4  1.000   1   0    0    1    2  240    1
# ..   ..    ...    ...  ..  ..  ..    ...  ..  ..  ...  ...  ...  ...  ...
# 531   1  43.00   0.29   1  13   8  1.750   1   1    8    0    2  100  376
# 532   1  31.57  10.50   2  14   4  6.500   1   0    0    0    2    0    1
# 533   0  18.83   9.54   2   6   4  0.085   1   0    0    0    2  100    1
# 534   0  27.42  14.50   2  14   8  3.085   1   1    1    0    2  120   12
# 535   1  41.00   0.04   2  10   4  0.040   0   1    1    0    1  560    1
#
# [536 rows x 14 columns]

# %%
y_undsamp_6 = merge_data_6["Class"]
y_undsamp_6
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 531    1
# 532    1
# 533    1
# 534    1
# 535    1
# Name: Class, Length: 536, dtype: int64

# %%
y_undsamp_6.value_counts()
# Out:
# 1    307
# 0    229
# Name: Class, dtype: int64

# %%
import matplotlib.pyplot as plt
from matplotlib.figure import Figure

fig_6 = plt.figure(figsize=(4, 4))
fig_6.suptitle("Original Data")
chart_6 = y_undsamp_6.value_counts()
labels_class = ["1", "0"]
plt.pie(chart_6, autopct="%.2f", labels=labels_class)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="400">

# %%
from imblearn.under_sampling import RandomUnderSampler

rus_6 = RandomUnderSampler(sampling_strategy=1)
X_res_6, y_res_6 = rus_6.fit_resample(x_undsamp_6, y_undsamp_6)
fig_6 = plt.figure(figsize=(4, 4))

plt.pie(y_res_6.value_counts(), autopct="%.2f", labels=labels_class)
plt.title("Under-sampling")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="400">

# %%
y_res_6.value_counts()
# Out:
# 0    229
# 1    229
# Name: Class, dtype: int64

# %% [markdown]
# ## Dokonuje sprawdzenia jakości pięciu klasyfikatorów po zastosowaniu metody under_sampling takich jak :
#     1.LogisticRegression
#     2.LinearDiscriminantAnalysis
#     3.DecisionTreeClassifier
#     4.KNeighborsClassifier
#     5.SVC(Support Vector Classification)

# %%
models_undsamp_6 = []
models_undsamp_6.append(("LR", LogisticRegression(solver="lbfgs", max_iter=3000)))
models_undsamp_6.append(("LDA", LinearDiscriminantAnalysis()))
models_undsamp_6.append(("KNN", KNeighborsClassifier()))
models_undsamp_6.append(("DSC", DecisionTreeClassifier(random_state=1, max_depth=2)))
models_undsamp_6.append(("SVM", SVC()))
# evaluate each model in turn
results_undsamp = []
names_undsamp = []
for name, model in models_undsamp_6:
    kfold = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
    cv_results = cross_val_score(
        model, X_res_6, y_res_6, cv=kfold, scoring="balanced_accuracy"
    )
    results.append(cv_results)
    names.append(name)
    msg = "%s: %.2f (%.3f)" % (name, cv_results.mean(), cv_results.std())
    print(msg)
# Out:
# LR: 0.84 (0.051)
# LDA: 0.84 (0.041)
# KNN: 0.60 (0.061)
# DSC: 0.84 (0.042)
# SVM: 0.60 (0.048)

# %% [markdown]
# # Dokonuje poprawy jakośći klasyfikatorów przy użyciu metody Over-sampling

# %% [markdown]
# ### Dla pierwszego zbioru danych

# %%
from imblearn.over_sampling import RandomOverSampler

X_over_1 = merge_data_1.drop(["Class"], axis=1)
X_over_1
# Out:
#      A1     A2     A3  A4  A5  A6     A7  A8  A9  A10  A11  A12  A13  A14
# 0     0  26.17   2.00   2   5   3  0.000   0   0    0    1    2  276    2
# 1     1  20.00   7.00   2   8   4  0.500   0   0    0    0    2    0    1
# 2     1  19.42   1.50   1  13   4  2.000   1   0    0    1    2  100   21
# 3     0  18.17  10.00   1  11   8  0.165   0   0    0    0    2  340    1
# 4     1  34.00   4.50   2   6   4  1.000   1   0    0    1    2  240    1
# ..   ..    ...    ...  ..  ..  ..    ...  ..  ..  ...  ...  ...  ...  ...
# 340   1  43.00   0.29   1  13   8  1.750   1   1    8    0    2  100  376
# 341   1  31.57  10.50   2  14   4  6.500   1   0    0    0    2    0    1
# 342   0  18.83   9.54   2   6   4  0.085   1   0    0    0    2  100    1
# 343   0  27.42  14.50   2  14   8  3.085   1   1    1    0    2  120   12
# 344   1  41.00   0.04   2  10   4  0.040   0   1    1    0    1  560    1
#
# [345 rows x 14 columns]

# %%
Y_over_1 = merge_data_1["Class"]
Y_over_1
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 340    1
# 341    1
# 342    1
# 343    1
# 344    1
# Name: Class, Length: 345, dtype: int64

# %%
Y_over_1.value_counts()
# Out:
# 1    307
# 0     38
# Name: Class, dtype: int64

# %%
ros_1 = RandomOverSampler(random_state=0)
x_oversamp_1, y_oversamp_1 = ros_1.fit_resample(X_over_1, Y_over_1)

# %%
y_oversamp_1.value_counts()
# Out:
# 0    307
# 1    307
# Name: Class, dtype: int64

# %%
models_oversamp_1 = []
models_oversamp_1.append(("LR", LogisticRegression(solver="lbfgs", max_iter=3000)))
models_oversamp_1.append(("LDA", LinearDiscriminantAnalysis()))
models_oversamp_1.append(("KNN", KNeighborsClassifier()))
models_oversamp_1.append(("DSC", DecisionTreeClassifier(random_state=1, max_depth=2)))
models_oversamp_1.append(("SVM", SVC()))
# evaluate each model in turn
results_oversamp = []
names_oversamp = []
for name, model in models_oversamp_1:
    kfold = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
    cv_results = cross_val_score(
        model, x_oversamp_1, y_oversamp_1, cv=kfold, scoring="balanced_accuracy",
    )
    results_oversamp.append(cv_results)
    names_oversamp.append(name)
    msg = "%s: %.2f (%.3f)" % (name, cv_results.mean(), cv_results.std())
    print(msg)
# Out:
# LR: 0.88 (0.032)
# LDA: 0.88 (0.032)
# KNN: 0.87 (0.034)
# DSC: 0.87 (0.030)
# SVM: 0.63 (0.044)

# %% [markdown]
# ### Dla drugiego zbioru danych

# %%
X_over_2 = merge_data_2.drop(["Class"], axis=1)
X_over_2
# Out:
#      A1     A2     A3  A4  A5  A6     A7  A8  A9  A10  A11  A12  A13  A14
# 0     0  26.17   2.00   2   5   3  0.000   0   0    0    1    2  276    2
# 1     1  20.00   7.00   2   8   4  0.500   0   0    0    0    2    0    1
# 2     1  19.42   1.50   1  13   4  2.000   1   0    0    1    2  100   21
# 3     0  18.17  10.00   1  11   8  0.165   0   0    0    0    2  340    1
# 4     1  34.00   4.50   2   6   4  1.000   1   0    0    1    2  240    1
# ..   ..    ...    ...  ..  ..  ..    ...  ..  ..  ...  ...  ...  ...  ...
# 378   1  43.00   0.29   1  13   8  1.750   1   1    8    0    2  100  376
# 379   1  31.57  10.50   2  14   4  6.500   1   0    0    0    2    0    1
# 380   0  18.83   9.54   2   6   4  0.085   1   0    0    0    2  100    1
# 381   0  27.42  14.50   2  14   8  3.085   1   1    1    0    2  120   12
# 382   1  41.00   0.04   2  10   4  0.040   0   1    1    0    1  560    1
#
# [383 rows x 14 columns]

# %%
Y_over_2 = merge_data_2["Class"]
Y_over_2
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 378    1
# 379    1
# 380    1
# 381    1
# 382    1
# Name: Class, Length: 383, dtype: int64

# %%
Y_over_2.value_counts()
# Out:
# 1    307
# 0     76
# Name: Class, dtype: int64

# %%
ros_2 = RandomOverSampler(random_state=0)
x_oversamp_2, y_oversamp_2 = ros_2.fit_resample(X_over_2, Y_over_2)

# %%
y_oversamp_2.value_counts()
# Out:
# 0    307
# 1    307
# Name: Class, dtype: int64

# %%
models_oversamp_2 = []
models_oversamp_2.append(("LR", LogisticRegression(solver="lbfgs", max_iter=3000)))
models_oversamp_2.append(("LDA", LinearDiscriminantAnalysis()))
models_oversamp_2.append(("KNN", KNeighborsClassifier()))
models_oversamp_2.append(("DSC", DecisionTreeClassifier(random_state=1, max_depth=2)))
models_oversamp_2.append(("SVM", SVC()))
# evaluate each model in turn
results_oversamp_2 = []
names_oversamp_2 = []
for name, model in models_oversamp_2:
    kfold = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
    cv_results = cross_val_score(
        model, x_oversamp_2, y_oversamp_2, cv=kfold, scoring="balanced_accuracy",
    )
    results_oversamp_2.append(cv_results)
    names_oversamp_2.append(name)
    msg = "%s: %.2f (%.3f)" % (name, cv_results.mean(), cv_results.std())
    print(msg)
# Out:
# LR: 0.83 (0.042)
# LDA: 0.85 (0.039)
# KNN: 0.76 (0.055)
# DSC: 0.84 (0.039)
# SVM: 0.61 (0.050)

# %% [markdown]
# ### Dla trzeciego zbioru danych

# %%
X_over_3 = merge_data_3.drop(["Class"], axis=1)
X_over_3
# Out:
#      A1     A2     A3  A4  A5  A6     A7  A8  A9  A10  A11  A12  A13  A14
# 0     0  26.17   2.00   2   5   3  0.000   0   0    0    1    2  276    2
# 1     1  20.00   7.00   2   8   4  0.500   0   0    0    0    2    0    1
# 2     1  19.42   1.50   1  13   4  2.000   1   0    0    1    2  100   21
# 3     0  18.17  10.00   1  11   8  0.165   0   0    0    0    2  340    1
# 4     1  34.00   4.50   2   6   4  1.000   1   0    0    1    2  240    1
# ..   ..    ...    ...  ..  ..  ..    ...  ..  ..  ...  ...  ...  ...  ...
# 416   1  43.00   0.29   1  13   8  1.750   1   1    8    0    2  100  376
# 417   1  31.57  10.50   2  14   4  6.500   1   0    0    0    2    0    1
# 418   0  18.83   9.54   2   6   4  0.085   1   0    0    0    2  100    1
# 419   0  27.42  14.50   2  14   8  3.085   1   1    1    0    2  120   12
# 420   1  41.00   0.04   2  10   4  0.040   0   1    1    0    1  560    1
#
# [421 rows x 14 columns]

# %%
Y_over_3 = merge_data_3["Class"]
Y_over_3
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 416    1
# 417    1
# 418    1
# 419    1
# 420    1
# Name: Class, Length: 421, dtype: int64

# %%
Y_over_3.value_counts()
# Out:
# 1    307
# 0    114
# Name: Class, dtype: int64

# %%
ros_3 = RandomOverSampler(random_state=0)
x_oversamp_3, y_oversamp_3 = ros_3.fit_resample(X_over_3, Y_over_3)

# %%
y_oversamp_3.value_counts()
# Out:
# 0    307
# 1    307
# Name: Class, dtype: int64

# %%
models_oversamp_3 = []
models_oversamp_3.append(("LR", LogisticRegression(solver="lbfgs", max_iter=3000)))
models_oversamp_3.append(("LDA", LinearDiscriminantAnalysis()))
models_oversamp_3.append(("KNN", KNeighborsClassifier()))
models_oversamp_3.append(("DSC", DecisionTreeClassifier(random_state=1, max_depth=2)))
models_oversamp_3.append(("SVM", SVC()))
# evaluate each model in turn
results_oversamp_3 = []
names_oversamp_3 = []
for name, model in models_oversamp_3:
    kfold = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
    cv_results = cross_val_score(
        model, x_oversamp_3, y_oversamp_3, cv=kfold, scoring="balanced_accuracy",
    )
    results_oversamp_3.append(cv_results)
    names_oversamp_3.append(name)
    msg = "%s: %.2f (%.3f)" % (name, cv_results.mean(), cv_results.std())
    print(msg)
# Out:
# LR: 0.85 (0.052)
# LDA: 0.85 (0.059)
# KNN: 0.71 (0.059)
# DSC: 0.84 (0.056)
# SVM: 0.62 (0.040)

# %% [markdown]
# ### Dla czwartego zbioru danych

# %%
X_over_4 = merge_data_4.drop(["Class"], axis=1)
X_over_4
# Out:
#      A1     A2     A3  A4  A5  A6     A7  A8  A9  A10  A11  A12  A13  A14
# 0     0  26.17   2.00   2   5   3  0.000   0   0    0    1    2  276    2
# 1     1  20.00   7.00   2   8   4  0.500   0   0    0    0    2    0    1
# 2     1  19.42   1.50   1  13   4  2.000   1   0    0    1    2  100   21
# 3     0  18.17  10.00   1  11   8  0.165   0   0    0    0    2  340    1
# 4     1  34.00   4.50   2   6   4  1.000   1   0    0    1    2  240    1
# ..   ..    ...    ...  ..  ..  ..    ...  ..  ..  ...  ...  ...  ...  ...
# 455   1  43.00   0.29   1  13   8  1.750   1   1    8    0    2  100  376
# 456   1  31.57  10.50   2  14   4  6.500   1   0    0    0    2    0    1
# 457   0  18.83   9.54   2   6   4  0.085   1   0    0    0    2  100    1
# 458   0  27.42  14.50   2  14   8  3.085   1   1    1    0    2  120   12
# 459   1  41.00   0.04   2  10   4  0.040   0   1    1    0    1  560    1
#
# [460 rows x 14 columns]

# %%
Y_over_4 = merge_data_4["Class"]
Y_over_4
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 455    1
# 456    1
# 457    1
# 458    1
# 459    1
# Name: Class, Length: 460, dtype: int64

# %%
Y_over_4.value_counts()
# Out:
# 1    307
# 0    153
# Name: Class, dtype: int64

# %%
ros_4 = RandomOverSampler(random_state=0)
x_oversamp_4, y_oversamp_4 = ros_4.fit_resample(X_over_4, Y_over_4)

# %%
y_oversamp_4.value_counts()
# Out:
# 0    307
# 1    307
# Name: Class, dtype: int64

# %%
models_oversamp_4 = []
models_oversamp_4.append(("LR", LogisticRegression(solver="lbfgs", max_iter=3000)))
models_oversamp_4.append(("LDA", LinearDiscriminantAnalysis()))
models_oversamp_4.append(("KNN", KNeighborsClassifier()))
models_oversamp_4.append(("DSC", DecisionTreeClassifier(random_state=1, max_depth=2)))
models_oversamp_4.append(("SVM", SVC()))
# evaluate each model in turn
results_oversamp_4 = []
names_oversamp_4 = []
for name, model in models_oversamp_4:
    kfold = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
    cv_results = cross_val_score(
        model, x_oversamp_4, y_oversamp_4, cv=kfold, scoring="balanced_accuracy",
    )
    results_oversamp_4.append(cv_results)
    names_oversamp_4.append(name)
    msg = "%s: %.2f (%.3f)" % (name, cv_results.mean(), cv_results.std())
    print(msg)
# Out:
# LR: 0.86 (0.056)
# LDA: 0.85 (0.060)
# KNN: 0.67 (0.048)
# DSC: 0.85 (0.054)
# SVM: 0.63 (0.043)

# %% [markdown]
# ### Dla piątego zbioru danych

# %%
X_over_5 = merge_data_5.drop(["Class"], axis=1)
X_over_5
# Out:
#      A1     A2     A3  A4  A5  A6     A7  A8  A9  A10  A11  A12  A13  A14
# 0     0  26.17   2.00   2   5   3  0.000   0   0    0    1    2  276    2
# 1     1  20.00   7.00   2   8   4  0.500   0   0    0    0    2    0    1
# 2     1  19.42   1.50   1  13   4  2.000   1   0    0    1    2  100   21
# 3     0  18.17  10.00   1  11   8  0.165   0   0    0    0    2  340    1
# 4     1  34.00   4.50   2   6   4  1.000   1   0    0    1    2  240    1
# ..   ..    ...    ...  ..  ..  ..    ...  ..  ..  ...  ...  ...  ...  ...
# 493   1  43.00   0.29   1  13   8  1.750   1   1    8    0    2  100  376
# 494   1  31.57  10.50   2  14   4  6.500   1   0    0    0    2    0    1
# 495   0  18.83   9.54   2   6   4  0.085   1   0    0    0    2  100    1
# 496   0  27.42  14.50   2  14   8  3.085   1   1    1    0    2  120   12
# 497   1  41.00   0.04   2  10   4  0.040   0   1    1    0    1  560    1
#
# [498 rows x 14 columns]

# %%
Y_over_5 = merge_data_5["Class"]
Y_over_5
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 493    1
# 494    1
# 495    1
# 496    1
# 497    1
# Name: Class, Length: 498, dtype: int64

# %%
Y_over_5.value_counts()
# Out:
# 1    307
# 0    191
# Name: Class, dtype: int64

# %%
ros_5 = RandomOverSampler(random_state=0)
x_oversamp_5, y_oversamp_5 = ros_5.fit_resample(X_over_5, Y_over_5)

# %%
models_oversamp_5 = []
models_oversamp_5.append(("LR", LogisticRegression(solver="lbfgs", max_iter=3000)))
models_oversamp_5.append(("LDA", LinearDiscriminantAnalysis()))
models_oversamp_5.append(("KNN", KNeighborsClassifier()))
models_oversamp_5.append(("DSC", DecisionTreeClassifier(random_state=1, max_depth=2)))
models_oversamp_5.append(("SVM", SVC()))
# evaluate each model in turn
results_oversamp_5 = []
names_oversamp_5 = []
for name, model in models_oversamp_5:
    kfold = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
    cv_results = cross_val_score(
        model, x_oversamp_5, y_oversamp_5, cv=kfold, scoring="balanced_accuracy",
    )
    results_oversamp_5.append(cv_results)
    names_oversamp_5.append(name)
    msg = "%s: %.2f (%.3f)" % (name, cv_results.mean(), cv_results.std())
    print(msg)
# Out:
# LR: 0.86 (0.050)
# LDA: 0.85 (0.052)
# KNN: 0.67 (0.045)
# DSC: 0.86 (0.048)
# SVM: 0.62 (0.038)

# %% [markdown]
# ### Dla szóstego zbioru danych

# %%
X_over_6 = merge_data_6.drop(["Class"], axis=1)
X_over_6
# Out:
#      A1     A2     A3  A4  A5  A6     A7  A8  A9  A10  A11  A12  A13  A14
# 0     0  26.17   2.00   2   5   3  0.000   0   0    0    1    2  276    2
# 1     1  20.00   7.00   2   8   4  0.500   0   0    0    0    2    0    1
# 2     1  19.42   1.50   1  13   4  2.000   1   0    0    1    2  100   21
# 3     0  18.17  10.00   1  11   8  0.165   0   0    0    0    2  340    1
# 4     1  34.00   4.50   2   6   4  1.000   1   0    0    1    2  240    1
# ..   ..    ...    ...  ..  ..  ..    ...  ..  ..  ...  ...  ...  ...  ...
# 531   1  43.00   0.29   1  13   8  1.750   1   1    8    0    2  100  376
# 532   1  31.57  10.50   2  14   4  6.500   1   0    0    0    2    0    1
# 533   0  18.83   9.54   2   6   4  0.085   1   0    0    0    2  100    1
# 534   0  27.42  14.50   2  14   8  3.085   1   1    1    0    2  120   12
# 535   1  41.00   0.04   2  10   4  0.040   0   1    1    0    1  560    1
#
# [536 rows x 14 columns]

# %%
Y_over_6 = merge_data_6["Class"]
Y_over_6
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 531    1
# 532    1
# 533    1
# 534    1
# 535    1
# Name: Class, Length: 536, dtype: int64

# %%
Y_over_6.value_counts()
# Out:
# 1    307
# 0    229
# Name: Class, dtype: int64

# %%
ros_6 = RandomOverSampler(random_state=0)
x_oversamp_6, y_oversamp_6 = ros_6.fit_resample(X_over_6, Y_over_6)

# %%
y_oversamp_6.value_counts()
# Out:
# 0    307
# 1    307
# Name: Class, dtype: int64

# %%
models_oversamp_6 = []
models_oversamp_6.append(("LR", LogisticRegression(solver="lbfgs", max_iter=3000)))
models_oversamp_6.append(("LDA", LinearDiscriminantAnalysis()))
models_oversamp_6.append(("KNN", KNeighborsClassifier()))
models_oversamp_6.append(("DSC", DecisionTreeClassifier(random_state=1, max_depth=2)))
models_oversamp_6.append(("SVM", SVC()))
# evaluate each model in turn
results_oversamp_6 = []
names_oversamp_6 = []
for name, model in models_oversamp_6:
    kfold = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
    cv_results = cross_val_score(
        model, x_oversamp_6, y_oversamp_6, cv=kfold, scoring="balanced_accuracy",
    )
    results_oversamp_6.append(cv_results)
    names_oversamp_6.append(name)
    msg = "%s: %.2f (%.3f)" % (name, cv_results.mean(), cv_results.std())
    print(msg)
# Out:
# LR: 0.85 (0.043)
# LDA: 0.85 (0.048)
# KNN: 0.66 (0.054)
# DSC: 0.85 (0.043)
# SVM: 0.62 (0.046)

# %% [markdown]
# # Dokonuje poprawy jakośći klasyfikatorów przy użyciu metody SMOTE

# %% [markdown]
# ### Dla pierwszego zbioru

# %%
from imblearn.over_sampling import SMOTE
smote = SMOTE()

# %%
x_smote_1 = merge_data_1.drop(["Class"], axis=1)
x_smote_1
# Out:
#      A1     A2     A3  A4  A5  A6     A7  A8  A9  A10  A11  A12  A13  A14
# 0     0  26.17   2.00   2   5   3  0.000   0   0    0    1    2  276    2
# 1     1  20.00   7.00   2   8   4  0.500   0   0    0    0    2    0    1
# 2     1  19.42   1.50   1  13   4  2.000   1   0    0    1    2  100   21
# 3     0  18.17  10.00   1  11   8  0.165   0   0    0    0    2  340    1
# 4     1  34.00   4.50   2   6   4  1.000   1   0    0    1    2  240    1
# ..   ..    ...    ...  ..  ..  ..    ...  ..  ..  ...  ...  ...  ...  ...
# 340   1  43.00   0.29   1  13   8  1.750   1   1    8    0    2  100  376
# 341   1  31.57  10.50   2  14   4  6.500   1   0    0    0    2    0    1
# 342   0  18.83   9.54   2   6   4  0.085   1   0    0    0    2  100    1
# 343   0  27.42  14.50   2  14   8  3.085   1   1    1    0    2  120   12
# 344   1  41.00   0.04   2  10   4  0.040   0   1    1    0    1  560    1
#
# [345 rows x 14 columns]

# %%
y_smote_1 = merge_data_1["Class"]
y_smote_1
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 340    1
# 341    1
# 342    1
# 343    1
# 344    1
# Name: Class, Length: 345, dtype: int64

# %%
y_smote_1.value_counts()
# Out:
# 1    307
# 0     38
# Name: Class, dtype: int64

# %%
x_train_smote_1, y_train_smote_1 = smote.fit_resample(x_smote_1, y_smote_1)

# %%
y_train_smote_1.value_counts()
# Out:
# 0    307
# 1    307
# Name: Class, dtype: int64

# %%
models_smote_1 = []
models_smote_1.append(("LR", LogisticRegression(solver="lbfgs", max_iter=3000)))
models_smote_1.append(("LDA", LinearDiscriminantAnalysis()))
models_smote_1.append(("KNN", KNeighborsClassifier()))
models_smote_1.append(("DSC", DecisionTreeClassifier(random_state=1, max_depth=2)))
models_smote_1.append(("SVM", SVC()))
# evaluate each model in turn
results_smote_1 = []
names_smote_1 = []
for name, model in models_smote_1:
    kfold = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
    cv_results = cross_val_score(
        model, x_train_smote_1, y_train_smote_1, cv=kfold, scoring="balanced_accuracy",
    )
    results_smote_1.append(cv_results)
    names_smote_1.append(name)
    msg = "%s: %.2f (%.3f)" % (name, cv_results.mean(), cv_results.std())
    print(msg)
# Out:
# LR: 0.94 (0.030)
# LDA: 0.93 (0.026)
# KNN: 0.79 (0.059)
# DSC: 0.94 (0.027)
# SVM: 0.64 (0.044)

# %% [markdown]
# ### Dla drugiego zbioru

# %%
x_smote_2 = merge_data_2.drop(["Class"], axis=1)
x_smote_2
# Out:
#      A1     A2     A3  A4  A5  A6     A7  A8  A9  A10  A11  A12  A13  A14
# 0     0  26.17   2.00   2   5   3  0.000   0   0    0    1    2  276    2
# 1     1  20.00   7.00   2   8   4  0.500   0   0    0    0    2    0    1
# 2     1  19.42   1.50   1  13   4  2.000   1   0    0    1    2  100   21
# 3     0  18.17  10.00   1  11   8  0.165   0   0    0    0    2  340    1
# 4     1  34.00   4.50   2   6   4  1.000   1   0    0    1    2  240    1
# ..   ..    ...    ...  ..  ..  ..    ...  ..  ..  ...  ...  ...  ...  ...
# 378   1  43.00   0.29   1  13   8  1.750   1   1    8    0    2  100  376
# 379   1  31.57  10.50   2  14   4  6.500   1   0    0    0    2    0    1
# 380   0  18.83   9.54   2   6   4  0.085   1   0    0    0    2  100    1
# 381   0  27.42  14.50   2  14   8  3.085   1   1    1    0    2  120   12
# 382   1  41.00   0.04   2  10   4  0.040   0   1    1    0    1  560    1
#
# [383 rows x 14 columns]

# %%
y_smote_2 = merge_data_2["Class"]
y_smote_2
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 378    1
# 379    1
# 380    1
# 381    1
# 382    1
# Name: Class, Length: 383, dtype: int64

# %%
y_smote_2.value_counts()
# Out:
# 1    307
# 0     76
# Name: Class, dtype: int64

# %%
x_train_smote_2, y_train_smote_2 = smote.fit_resample(x_smote_2, y_smote_2)

# %%
y_train_smote_2.value_counts()
# Out:
# 0    307
# 1    307
# Name: Class, dtype: int64

# %%
models_smote_2 = []
models_smote_2.append(("LR", LogisticRegression(solver="lbfgs", max_iter=3000)))
models_smote_2.append(("LDA", LinearDiscriminantAnalysis()))
models_smote_2.append(("KNN", KNeighborsClassifier()))
models_smote_2.append(("DSC", DecisionTreeClassifier(random_state=1, max_depth=2)))
models_smote_2.append(("SVM", SVC()))
# evaluate each model in turn
results_smote_2 = []
names_smote_2 = []
for name, model in models_smote_2:
    kfold = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
    cv_results = cross_val_score(
        model, x_train_smote_2, y_train_smote_2, cv=kfold, scoring="balanced_accuracy",
    )
    results_smote_2.append(cv_results)
    names_smote_2.append(name)
    msg = "%s: %.2f (%.3f)" % (name, cv_results.mean(), cv_results.std())
    print(msg)
# Out:
# LR: 0.90 (0.049)
# LDA: 0.91 (0.047)
# KNN: 0.77 (0.041)
# DSC: 0.91 (0.044)
# SVM: 0.64 (0.039)

# %% [markdown]
# ### Dla trzeciego zbioru

# %%
x_smote_3 = merge_data_3.drop(["Class"], axis=1)
x_smote_3
# Out:
#      A1     A2     A3  A4  A5  A6     A7  A8  A9  A10  A11  A12  A13  A14
# 0     0  26.17   2.00   2   5   3  0.000   0   0    0    1    2  276    2
# 1     1  20.00   7.00   2   8   4  0.500   0   0    0    0    2    0    1
# 2     1  19.42   1.50   1  13   4  2.000   1   0    0    1    2  100   21
# 3     0  18.17  10.00   1  11   8  0.165   0   0    0    0    2  340    1
# 4     1  34.00   4.50   2   6   4  1.000   1   0    0    1    2  240    1
# ..   ..    ...    ...  ..  ..  ..    ...  ..  ..  ...  ...  ...  ...  ...
# 416   1  43.00   0.29   1  13   8  1.750   1   1    8    0    2  100  376
# 417   1  31.57  10.50   2  14   4  6.500   1   0    0    0    2    0    1
# 418   0  18.83   9.54   2   6   4  0.085   1   0    0    0    2  100    1
# 419   0  27.42  14.50   2  14   8  3.085   1   1    1    0    2  120   12
# 420   1  41.00   0.04   2  10   4  0.040   0   1    1    0    1  560    1
#
# [421 rows x 14 columns]

# %%
y_smote_3 = merge_data_3["Class"]
y_smote_3
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 416    1
# 417    1
# 418    1
# 419    1
# 420    1
# Name: Class, Length: 421, dtype: int64

# %%
y_smote_3.value_counts()
# Out:
# 1    307
# 0    114
# Name: Class, dtype: int64

# %%
x_train_smote_3, y_train_smote_3 = smote.fit_resample(x_smote_3, y_smote_3)

# %%
y_train_smote_3.value_counts()
# Out:
# 0    307
# 1    307
# Name: Class, dtype: int64

# %%
models_smote_3 = []
models_smote_3.append(("LR", LogisticRegression(solver="lbfgs", max_iter=3000)))
models_smote_3.append(("LDA", LinearDiscriminantAnalysis()))
models_smote_3.append(("KNN", KNeighborsClassifier()))
models_smote_3.append(("DSC", DecisionTreeClassifier(random_state=1, max_depth=2)))
models_smote_3.append(("SVM", SVC()))
# evaluate each model in turn
results_smote_3 = []
names_smote_3 = []
for name, model in models_smote_3:
    kfold = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
    cv_results = cross_val_score(
        model, x_train_smote_3, y_train_smote_3, cv=kfold, scoring="balanced_accuracy",
    )
    results_smote_3.append(cv_results)
    names_smote_3.append(name)
    msg = "%s: %.2f (%.3f)" % (name, cv_results.mean(), cv_results.std())
    print(msg)
# Out:
# LR: 0.90 (0.041)
# LDA: 0.89 (0.040)
# KNN: 0.72 (0.042)
# DSC: 0.90 (0.037)
# SVM: 0.63 (0.039)

# %% [markdown]
# ### Dla czwartego zbioru

# %%
x_smote_4 = merge_data_4.drop(["Class"], axis=1)
x_smote_4
# Out:
#      A1     A2     A3  A4  A5  A6     A7  A8  A9  A10  A11  A12  A13  A14
# 0     0  26.17   2.00   2   5   3  0.000   0   0    0    1    2  276    2
# 1     1  20.00   7.00   2   8   4  0.500   0   0    0    0    2    0    1
# 2     1  19.42   1.50   1  13   4  2.000   1   0    0    1    2  100   21
# 3     0  18.17  10.00   1  11   8  0.165   0   0    0    0    2  340    1
# 4     1  34.00   4.50   2   6   4  1.000   1   0    0    1    2  240    1
# ..   ..    ...    ...  ..  ..  ..    ...  ..  ..  ...  ...  ...  ...  ...
# 455   1  43.00   0.29   1  13   8  1.750   1   1    8    0    2  100  376
# 456   1  31.57  10.50   2  14   4  6.500   1   0    0    0    2    0    1
# 457   0  18.83   9.54   2   6   4  0.085   1   0    0    0    2  100    1
# 458   0  27.42  14.50   2  14   8  3.085   1   1    1    0    2  120   12
# 459   1  41.00   0.04   2  10   4  0.040   0   1    1    0    1  560    1
#
# [460 rows x 14 columns]

# %%
y_smote_4 = merge_data_4["Class"]
y_smote_4
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 455    1
# 456    1
# 457    1
# 458    1
# 459    1
# Name: Class, Length: 460, dtype: int64

# %%
y_smote_4.value_counts()
# Out:
# 1    307
# 0    153
# Name: Class, dtype: int64

# %%
x_train_smote_4, y_train_smote_4 = smote.fit_resample(x_smote_4, y_smote_4)

# %%
y_train_smote_4.value_counts()
# Out:
# 0    307
# 1    307
# Name: Class, dtype: int64

# %%
models_smote_4 = []
models_smote_4.append(("LR", LogisticRegression(solver="lbfgs", max_iter=3000)))
models_smote_4.append(("LDA", LinearDiscriminantAnalysis()))
models_smote_4.append(("KNN", KNeighborsClassifier()))
models_smote_4.append(("DSC", DecisionTreeClassifier(random_state=1, max_depth=2)))
models_smote_4.append(("SVM", SVC()))
# evaluate each model in turn
results_smote_4 = []
names_smote_4 = []
for name, model in models_smote_4:
    kfold = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
    cv_results = cross_val_score(
        model, x_train_smote_4, y_train_smote_4, cv=kfold, scoring="balanced_accuracy",
    )
    results_smote_4.append(cv_results)
    names_smote_4.append(name)
    msg = "%s: %.2f (%.3f)" % (name, cv_results.mean(), cv_results.std())
    print(msg)
# Out:
# LR: 0.89 (0.047)
# LDA: 0.88 (0.045)
# KNN: 0.73 (0.054)
# DSC: 0.88 (0.045)
# SVM: 0.65 (0.037)

# %% [markdown]
# ### Dla piątego zbioru

# %%
x_smote_5 = merge_data_5.drop(["Class"], axis=1)
x_smote_5
# Out:
#      A1     A2     A3  A4  A5  A6     A7  A8  A9  A10  A11  A12  A13  A14
# 0     0  26.17   2.00   2   5   3  0.000   0   0    0    1    2  276    2
# 1     1  20.00   7.00   2   8   4  0.500   0   0    0    0    2    0    1
# 2     1  19.42   1.50   1  13   4  2.000   1   0    0    1    2  100   21
# 3     0  18.17  10.00   1  11   8  0.165   0   0    0    0    2  340    1
# 4     1  34.00   4.50   2   6   4  1.000   1   0    0    1    2  240    1
# ..   ..    ...    ...  ..  ..  ..    ...  ..  ..  ...  ...  ...  ...  ...
# 493   1  43.00   0.29   1  13   8  1.750   1   1    8    0    2  100  376
# 494   1  31.57  10.50   2  14   4  6.500   1   0    0    0    2    0    1
# 495   0  18.83   9.54   2   6   4  0.085   1   0    0    0    2  100    1
# 496   0  27.42  14.50   2  14   8  3.085   1   1    1    0    2  120   12
# 497   1  41.00   0.04   2  10   4  0.040   0   1    1    0    1  560    1
#
# [498 rows x 14 columns]

# %%
y_smote_5 = merge_data_5["Class"]
y_smote_5
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 493    1
# 494    1
# 495    1
# 496    1
# 497    1
# Name: Class, Length: 498, dtype: int64

# %%
y_smote_5.value_counts()
# Out:
# 1    307
# 0    191
# Name: Class, dtype: int64

# %%
x_train_smote_5, y_train_smote_5 = smote.fit_resample(x_smote_5, y_smote_5)

# %%
y_train_smote_5.value_counts()
# Out:
# 0    307
# 1    307
# Name: Class, dtype: int64

# %%
models_smote_5 = []
models_smote_5.append(("LR", LogisticRegression(solver="lbfgs", max_iter=3000)))
models_smote_5.append(("LDA", LinearDiscriminantAnalysis()))
models_smote_5.append(("KNN", KNeighborsClassifier()))
models_smote_5.append(("DSC", DecisionTreeClassifier(random_state=1, max_depth=2)))
models_smote_5.append(("SVM", SVC()))
# evaluate each model in turn
results_smote_5 = []
names_smote_5 = []
for name, model in models_smote_5:
    kfold = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
    cv_results = cross_val_score(
        model, x_train_smote_5, y_train_smote_5, cv=kfold, scoring="balanced_accuracy",
    )
    results_smote_5.append(cv_results)
    names_smote_5.append(name)
    msg = "%s: %.2f (%.3f)" % (name, cv_results.mean(), cv_results.std())
    print(msg)
# Out:
# LR: 0.89 (0.049)
# LDA: 0.88 (0.051)
# KNN: 0.71 (0.047)
# DSC: 0.88 (0.049)
# SVM: 0.63 (0.041)

# %% [markdown]
# ### Dla szóstego zbioru

# %%
x_smote_6 = merge_data_6.drop(["Class"], axis=1)
x_smote_6
# Out:
#      A1     A2     A3  A4  A5  A6     A7  A8  A9  A10  A11  A12  A13  A14
# 0     0  26.17   2.00   2   5   3  0.000   0   0    0    1    2  276    2
# 1     1  20.00   7.00   2   8   4  0.500   0   0    0    0    2    0    1
# 2     1  19.42   1.50   1  13   4  2.000   1   0    0    1    2  100   21
# 3     0  18.17  10.00   1  11   8  0.165   0   0    0    0    2  340    1
# 4     1  34.00   4.50   2   6   4  1.000   1   0    0    1    2  240    1
# ..   ..    ...    ...  ..  ..  ..    ...  ..  ..  ...  ...  ...  ...  ...
# 531   1  43.00   0.29   1  13   8  1.750   1   1    8    0    2  100  376
# 532   1  31.57  10.50   2  14   4  6.500   1   0    0    0    2    0    1
# 533   0  18.83   9.54   2   6   4  0.085   1   0    0    0    2  100    1
# 534   0  27.42  14.50   2  14   8  3.085   1   1    1    0    2  120   12
# 535   1  41.00   0.04   2  10   4  0.040   0   1    1    0    1  560    1
#
# [536 rows x 14 columns]

# %%
y_smote_6 = merge_data_6["Class"]
y_smote_6
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 531    1
# 532    1
# 533    1
# 534    1
# 535    1
# Name: Class, Length: 536, dtype: int64

# %%
y_smote_6.value_counts()
# Out:
# 1    307
# 0    229
# Name: Class, dtype: int64

# %%
x_train_smote_6, y_train_smote_6 = smote.fit_resample(x_smote_6, y_smote_6)

# %%
y_train_smote_6.value_counts()
# Out:
# 0    307
# 1    307
# Name: Class, dtype: int64

# %%
models_smote_6 = []
models_smote_6.append(("LR", LogisticRegression(solver="lbfgs", max_iter=3000)))
models_smote_6.append(("LDA", LinearDiscriminantAnalysis()))
models_smote_6.append(("KNN", KNeighborsClassifier()))
models_smote_6.append(("DSC", DecisionTreeClassifier(random_state=1, max_depth=2)))
models_smote_6.append(("SVM", SVC()))
# evaluate each model in turn
results_smote_6 = []
names_smote_6 = []
for name, model in models_smote_6:
    kfold = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
    cv_results = cross_val_score(
        model, x_train_smote_6, y_train_smote_6, cv=kfold, scoring="balanced_accuracy",
    )
    results_smote_6.append(cv_results)
    names_smote_6.append(name)
    msg = "%s: %.2f (%.3f)" % (name, cv_results.mean(), cv_results.std())
    print(msg)
# Out:
# LR: 0.87 (0.041)
# LDA: 0.87 (0.046)
# KNN: 0.67 (0.054)
# DSC: 0.87 (0.040)
# SVM: 0.61 (0.045)

# %%
wyniki eksperymentu porównać dane w exelu
